# %%
import pandas as pd
df = pd.read_csv('score.csv')
df
# Out:
#     MathScore  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0          74           89.0           63.0               92            2020
# 1          75           94.0           64.0               75            2018
# 2          74           94.0           60.0               78            2018
# 3          78           84.0           65.0               77            2020
# 4          74           87.0           79.0               92            2019
# 5          78           87.0           74.0               76            2018
# 6          66           94.0           67.0               86            2018
# 7          64           92.0           70.0               89            2021
# 8          69           94.0           62.0               86            2018
# 9          64           77.0           68.0               90            2019
# 10         69           89.0           70.0               98            2019
# ...

# %%
df.isnull().sum()
# Out:
# MathScore          0
# Reading_Score      1
# Writing_Score      1
# Placement_Score    0
# Club_Join_Date     0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# MathScore          49
# Reading_Score      48
# Writing_Score      48
# Placement_Score    49
# Club_Join_Date     49
# dtype: int64

# %%
mv = df['Reading_Score'].mean()
mv
# Out:
# np.float64(85.41666666666667)

# %%
df['Reading_Score'] = df['Reading_Score'].fillna(mv)
df
# Out:
#     MathScore  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0          74      89.000000           63.0               92            2020
# 1          75      94.000000           64.0               75            2018
# 2          74      94.000000           60.0               78            2018
# 3          78      84.000000           65.0               77            2020
# 4          74      87.000000           79.0               92            2019
# 5          78      87.000000           74.0               76            2018
# 6          66      94.000000           67.0               86            2018
# 7          64      92.000000           70.0               89            2021
# 8          69      94.000000           62.0               86            2018
# 9          64      77.000000           68.0               90            2019
# 10         69      89.000000           70.0               98            2019
# ...

# %%
mv2 = df['Writing_Score'].min()
mv2
# Out:
# np.float64(60.0)

# %%
df['Writing_Score'] = df['Writing_Score'].fillna(mv2)
df
# Out:
#     MathScore  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0          74      89.000000           63.0               92            2020
# 1          75      94.000000           64.0               75            2018
# 2          74      94.000000           60.0               78            2018
# 3          78      84.000000           65.0               77            2020
# 4          74      87.000000           79.0               92            2019
# 5          78      87.000000           74.0               76            2018
# 6          66      94.000000           67.0               86            2018
# 7          64      92.000000           70.0               89            2021
# 8          69      94.000000           62.0               86            2018
# 9          64      77.000000           68.0               90            2019
# 10         69      89.000000           70.0               98            2019
# ...
